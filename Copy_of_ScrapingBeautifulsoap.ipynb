# %% [markdown]
# <a href="https://colab.research.google.com/github/gehadmaghawry17/Scraping-_website/blob/main/Copy_of_ScrapingBeautifulsoap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install googletrans==4.0.0-rc1

# %%
import requests
import re

# %%
from bs4 import BeautifulSoup
from googletrans import Translator

# %%
url = "https://www.classcentral.com/report/free-certificates/"

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36 Edg/110.0.1587.50'}

# %%
response = requests.get(url, headers=headers)

# %%
response = response.content

# %%
response

# %%
soup = BeautifulSoup(response,'html.parser')

# %%
soup

# %%
#test
text = soup.get_text()
print(text)
text_to_translate = re.sub(r'\W+', ' ', text) #get rid of extra spaces 
print('---------^^^^^^^^^^^^^^--------')
print(text_to_translate)
# Out:
# [2023] Massive List of Thousands of Free Certificates and Badges — Class Central
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
print(text_to_translate)
# Out:
#  2023 Massive List of Thousands of Free Certificates and Badges Class Central context https schema org graph type WebSite id https www classcentral com report website url https www classcentral com report name The Report by Class Central description MOOC News Interviews and Analysis potentialAction type SearchAction target type EntryPoint urlTemplate https www classcentral com report s search_term_string query input required name search_term_string inLanguage en US type ImageObject id https www classcentral com report free certificates primaryimage inLanguage en US url https www classcentral com report wp content uploads 2021 12 free certificates banner png contentUrl https www classcentral com report wp content uploads 2021 12 free certificates banner png width 1024 height 512 type WebPage id https www classcentral com report free certificates webpage url https www classcentral com report free certificates name 2023 Massive List of Thousands of Free Certificates and Badges Class Cen
# ...

# %%
soup

# %%
links = soup.find_all('a', class_='color-charcoal')

# %%
#good
for link in links:
    print(link['href'])
# Out:
# https://www.classcentral.com/report/author/ruima/
# https://www.classcentral.com/report/author/heba/
# https://www.classcentral.com/report/author/manoel/
# https://www.classcentral.com/report/author/suparn/
# https://www.classcentral.com/report/tag/free-certificates/
# https://www.classcentral.com/report/free-developer-it-certifications/
# https://www.classcentral.com/report/free-google-certifications/
# https://www.classcentral.com/report/free-online-learning-coronavirus/
# https://www.classcentral.com/report/free-digital-marketing-certificates/
# https://www.classcentral.com/about
# /subject/cs
# /subject/business
# /subject/humanities
# /subject/data-science
# /subject/personal-development
# /subject/art-and-design
# /subjects
# https://www.classcentral.com/subject/cs
# https://www.classcentral.com/subject/psychology
# https://www.classcentral.com/subject/cybersecurity
# https://www.classcentral.com/subject/health
# https://www.classcentral.com/subject/law
# ...

# %%
#good
links = []
for link in soup.find_all('a', href=True):
    if link['href'].startswith('http'):
        links.append(link['href'])

print(links)
# Out:
# ['https://www.classcentral.com/report/best-elm-courses/', 'https://www.classcentral.com/report/', 'https://www.classcentral.com/report/free-google-certifications/', 'https://www.classcentral.com', 'https://www.classcentral.com/subjects', 'https://www.classcentral.com/search', 'https://www.classcentral.com/write-a-review', 'https://www.classcentral.com/about', 'https://www.classcentral.com/report/category/mooc-news/', 'https://www.classcentral.com/report/category/analysis/', 'https://www.classcentral.com/report/category/features/', 'https://www.classcentral.com/report/category/guides/', 'https://www.classcentral.com/report/category/student-voices/', 'https://www.classcentral.com/collection/top-free-online-courses', 'https://www.classcentral.com/report/best-free-online-courses-2022/', 'https://www.classcentral.com/report/best-free-online-courses-2021/', 'https://www.classcentral.com/report/top-moocs-2020-edition/', 'https://www.classcentral.com/report/best-free-online-courses-2019/', '
# ...

# %%
from googletrans import Translator

# %%
text = soup.get_text()

# %%
url = 'https://www.classcentral.com/'

r = requests.get(url)
soup = BeautifulSoup(r.content, 'html.parser')

text = soup.get_text()

# %%
translator = Translator()
translated_text = translator.translate(text, dest='hi').text

print(translated_text)
